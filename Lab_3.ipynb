# %% [markdown]
# <a href="https://colab.research.google.com/github/KeerthiMasa/Fmml/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-21 10:03:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   131MB/s    in 0.5s
#
# 2025-04-21 10:03:10 (131 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13321   0912.0936v1  The emission rate of minority atmospheric gase...    cs
# 1209   1510.06706v1  Convolutional networks (ConvNets) have become ...    cs
# 16237  1611.01436v2  The reading comprehension task, that asks ques...    cs
# 9838    0903.4930v1  A technique for speeding up reinforcement lear...    cs
# 28898  1708.00042v1  In this work, we address the problem of spatio...    cs
# ...             ...                                                ...   ...
# 19059   1301.7406v1  I present a parallel algorithm for exact proba...    cs
# 22851  1709.01179v2  Two fundamental problems in unsupervised learn...  stat
# 2592   1608.02341v1  Probabilistic models learned as density estima...    cs
# 38411  1708.06872v2  We propose a new technique, Spectral Contextua...  stat
# 29661  1710.01084v1  In the quest for greater computer lip-reading ...    cs
#
#                                                    title  year  \
# 13321  Neural-estimator for the surface emission rate...  2009
# 1209   ZNN - A Fast and Scalable Algorithm for Traini...  2015
# 16237  Learning Recurrent Span Representations for Ex...  2016
# 9838   Time manipulation technique for speeding up re...  2009
# 28898  Spatio-Temporal Action Detection with Cascade ...  2017
# ...                                                  ...   ...
# 19059       Logarithmic Time Parallel Bayesian Inference  2013
# 22851  Continuous-Time Flows for Efficient Inference ...  2017
# 2592   Towards Representation Learning with Tractable...  2016
# 38411  Discovering Political Topics in Facebook Discu...  2017
# 29661  Some observations on computer lip-reading: mov...  2017
#
#                                                 keywords
# 13321  [atmospheric, perceptron, backpropagation, alg...
# 1209   [convolutional, important, accelerate, computa...
# 16237  [comprehension, questions, understanding, form...
# 9838   [technique, reinforcement, algorithms, manipul...
# 28898  [detection, temporally, untrimmed, important, ...
# ...                                                  ...
# 19059  [algorithm, probabilistic, inference, variable...
# 22851  [fundamental, unsupervised, efficient, inferen...
# 2592   [probabilistic, estimators, exploited, represe...
# 38411  [technique, contextualization, political, enga...
# 29661  [performance, assumptions, resolution, assumpt...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13321    [atmospheric, perceptron, backpropagation, alg...
# 1209     [convolutional, important, accelerate, computa...
# 16237    [comprehension, questions, understanding, form...
# 9838     [technique, reinforcement, algorithms, manipul...
# 28898    [detection, temporally, untrimmed, important, ...
#                                ...
# 6693     [algorithm, supervised, controversial, computa...
# 7697     [theoretical, understanding, attractive, viewp...
# 24859    [optimizing, riemannian, manifolds, classifica...
# 5018     [introduces, supervised, classification, algor...
# 15296    [probabilistic, participants, dirichlet, multi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8806 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f2a5dd7b-7f2a-4eb5-893b-c25e9bb141a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2a5dd7b-7f2a-4eb5-893b-c25e9bb141a1")) {                    Plotly.newPlot(                        "f2a5dd7b-7f2a-4eb5-893b-c25e9bb141a1",                        [{"x":["performed","inversion","atmospheric","significantly","estimator","approaches","backpropagation","identification","comparison","perceptron","regularized","algorithm","accelerate","compatible","attainable","dependency","depending","algorithms","computationally","convolution","convolutions","important","convergent","decomposition","parallelism","convolutional","implementations","converging","benchmarking","implement","specifics","architectures","concurrent","performance","architecture","computation","available","programming","processors","questions","candidates","efficiently","prediction","arbitrary","comprehension","extraction","extractive","decreases","answering","representations","published","selection","predictions","presenting","understanding","typically","formulations","recurrent","simulations","applicable","simulation","conventional","balancing","reinforcement","avoidance","backwards","manipulation","exploration","technique","anticipation","detections","consistencies","maximization","temporally","analyzing","localization","exploited","generation","conducted","challenging","effectiveness","independently","achieving","untrimmed","detection","demonstrate","additional","component","annotation","similarity","difficulty","different","dictionaries","automatically","generating","unstructured","presented","dictionary","structured","replacing","automated","intermediate","dirichlet","including","minibatch","experiments","optimization","stochastic","framework","corresponds","regression","superiority","motivates","consequently","necessity","reduction","computational","developed","convergence","practical","borrowing","theoretical","efficient","development","diagnosis","biomedical","approximately","describes","participation","participants","challenge","dermoscopic","concluded","international","classification","snapshots","segmentation","submissions","standardized","benchmark","comparative","collaboration","implementation","generated","knowledge","observations","represent","benefiting","information","dimensional","optimality","behaviors","designing","guarantees","sophisticated","experimentally","navigation","activations","termination","successful","probability","usefulness","possibility","vagueness","uncertain","especially","advocates","uncertainty","correction","translation","processing","distribution","strategies","experiment","generates","candidate","observation","fragments","automatic","incorrect","correctness","syntactic","corrections","corrector","proprietary","categorical","algorithmic","leveraging","completely","magnitude","certificate","alternative","interpretable","construct","according","consumption","empirical","structures","nonstationary","appropriate"],"y":[133,7,7,294,25,427,22,109,114,20,39,801,19,17,1,54,30,608,95,39,17,334,6,64,15,347,43,6,13,56,2,127,5,908,235,136,317,120,14,78,40,153,240,85,16,129,7,16,61,234,36,154,70,20,167,106,15,131,54,48,72,117,15,107,9,3,26,60,224,2,10,2,38,28,61,56,26,150,82,250,199,54,93,4,317,581,122,111,69,158,42,734,28,180,98,25,181,68,104,20,99,35,19,231,0,597,306,123,556,20,97,37,10,29,9,98,281,200,117,148,6,149,423,128,61,24,35,96,9,25,155,3,7,15,492,4,193,5,8,212,31,8,138,176,322,85,120,4,710,159,23,31,43,79,35,38,36,31,5,71,191,18,39,4,29,103,4,89,24,107,280,193,88,80,57,51,66,10,184,8,13,47,6,2,2,11,34,48,31,59,2,103,17,89,92,27,144,138,3,88],"type":"bar"},{"x":["performed","inversion","atmospheric","significantly","estimator ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Eigen</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>Distortions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.37243401759530786);'>Representations</span> <br/><br/><span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.37243401759530786);'>representations</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>explain</span> <span style='background-color:rgba(0, 255, 0, 0.7272727272727274);'>perceptual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitivity</span> <span style=''>in</span> <span style=''>humans</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>utilize</span> <span style=''>Fisher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>a</span> <span style=''>model</span> <span style=''>derived</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitivity</span> <span style=''>to</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbations</span> <span style=''>of</span> <span style=''>an</span> <span style=''>image</span> <span style=''>For</span> <span style=''>a</span> <span style=''>given</span> <span style=''>image</span> <span style=''>we</span> <span style=''>compute</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenvectors</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Fisher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>matrix</span> <span style=''>with</span> <span style=''>largest</span> <span style=''>and</span> <span style=''>smallest</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>eigenvalues</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363636);'>predicted</span> <span style=''>most</span> <span style=''>and</span> <span style=''>least</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>noticeable</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>distortions</span> <span style='background-color:rgba(0, 255, 0, 0.4146341463414634);'>respectively</span> <span style=''>For</span> <span style=''>human</span> <span style=''>subjects</span> <span style=''>we</span> <span style=''>then</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.6129032258064516);'>distortion</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>reliably</span> <span style=''>detected</span> <span style=''>when</span> <span style=''>added</span> <span style=''>to</span> <span style=''>the</span> <span style=''>image</span> <span style=''>We</span> <span style=''>use</span> <span style=''>this</span> <span style=''>method</span> <span style=''>to</span> <span style=''>test</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>of</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Anti</span> <span style=''>Profile</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>anti</span> <span style=''>profile</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>(apSVM)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>address</span> <span style=''>the</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>where</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinguish</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anomalous</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style=''>classes</span> <span style=''>based</span> <span style=''>on</span> <span style=''>their</span> <span style=''>pattern</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deviation</span> <span style=''>from</span> <span style=''>a</span> <span style=''>normal</span> <span style=''>stable</span> <span style=''>class</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>defined</span> <span style=''>here</span> <span style=''>that</span> <span style=''>the</span> <span style=''>apSVM</span> <span style=''>can</span> <span style=''>be</span> <span style=''>solved</span> <span style=''>as</span> <span style=''>the</span> <span style=''>dual</span> <span style=''>of</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>SVM</span> <span style=''>with</span> <span style=''>an</span> <span style=''>indirect</span> <span style=''>kernel</span> <span style=''>that</span> <span style=''>measures</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anomalous</span> <span style=''>samples</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>to</span> <span style=''>the</span> <span style=''>stable</span> <span style=''>normal</span> <span style=''>class</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style=''>this</span> <span style=''>indirect</span> <span style=''>kernel</span> <span style=''>as</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Space</span> <span style=''>between</span> <span style=''>representers</span> <span style=''>that</span> <span style=''>are</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Tight</span> <span style=''>Sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Complexity</span> <span style=''>of</span> <span style=''>Large</span> <span style=''>Margin</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>tight</span> <span style='background-color:rgba(255, 0, 0, 0.34907251264755484);'>distribution</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>large</span> <span style=''>margin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>with</span> <span style=''>L</span> <span style=''>2</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>gamma</span> <span style=''>adapted</span> <span style='background-color:rgba(255, 0, 0, 0.32367149758454106);'>dimension</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>spectrum</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3879781420765027);'>distributions</span> <span style='background-color:rgba(255, 0, 0, 0.6302521008403361);'>covariance</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.34907251264755484);'>distribution</span> <span style=''>specific</span> <span style=''>upper</span> <span style=''>and</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>both</span> <span style=''>governed</span> <span style=''>by</span> <span style=''>the</span> <span style=''>gamma</span> <span style=''>adapted</span> <span style='background-color:rgba(255, 0, 0, 0.32367149758454106);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>source</span> <span style='background-color:rgba(255, 0, 0, 0.34907251264755484);'>distribution</span> <span style=''>We</span> <span style=''>conclude</span> <span style=''>that</span> <span style=''>this</span> <span style=''>new</span> <span style=''>quantity</span> <span style=''>tightly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterizes</span> <span style=''>the</span> <span style=''>true</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>large</span> <span style=''>margin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>The</span> <span style=''>bounds</span> <span style=''>hold</span> <span style=''>for</span> <span style=''>a</span> <span style=''>rich</span> <span style=''>family</span> <span style=''>of</span> <span style=''>sub</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3879781420765027);'>distributions</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Integrated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>and</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Neural</span> <span style=''>Factors</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structural</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <br/><br/><span style=''>Tackling</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>areas</span> <span style=''>such</span> <span style=''>as</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bioinformatics</span> <span style=''>speech</span> <span style=''>or</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>is</span> <span style=''>often</span> <span style=''>done</span> <span style=''>best</span> <span style=''>by</span> <span style=''>taking</span> <span style=''>into</span> <span style=''>account</span> <span style=''>task</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>between</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>this</span> <span style=''>internal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>multiple</span> <span style=''>outputs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>and</span> <span style=''>coherent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structural</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>(SSVMs)</span> <span style=''>are</span> <span style=''>nonprobabilistic</span> <span style=''>models</span> <span style=''>that</span> <span style=''>optimize</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>input</span> <span style=''>output</span> <span style=''>function</span> <span style=''>through</span> <span style=''>margin</span> <span style=''>based</span> <span style=''>learning</span> <span style=''>Because</span> <span style=''>SSVMs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disregard</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interplay</span> <span style=''>between</span> <span style=''>unary</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>factors</span> <span style=''>during</span> <span style=''>the</span> <span style=''>training</span> <span style=''>phase</span> <span style=''>final</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimal</span> <span style=''>Moreover</span> <span style=''>its</span> <span style=''>factors</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>to</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12230470130788264)
# 	processing (0.09897490279250619)
# 	experimental (0.12548603746907033)
# 	segmentation (0.06822198656769177)
# 	architecture (0.08306822198656769)
# 	detection (0.1120537292329445)
# 	information (0.25097207493814067)
# 	different (0.2594556380346412)
# 	convolutional (0.12265818310357017)
# 	recognition (0.12548603746907033)
#
# Some Statistics words are:
# 	variables (0.1445966514459665)
# 	stochastic (0.1445966514459665)
# 	statistical (0.15575849822425164)
# 	theoretical (0.15423642820903094)
# 	estimation (0.1719939117199391)
# 	algorithm (0.4048706240487062)
# 	inference (0.2054794520547945)
# 	dimensional (0.1887366818873668)
# 	distribution (0.20294266869609334)
# 	regression (0.19888381532217148)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="69651bd7-62ac-4198-a525-6f2545398892" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69651bd7-62ac-4198-a525-6f2545398892")) {                    Plotly.newPlot(                        "69651bd7-62ac-4198-a525-6f2545398892",                        [{"x":["performed","inversion","atmospheric","significantly","estimator","approaches","backpropagation","identification","comparison","perceptron","regularized","algorithm","accelerate","compatible","attainable","dependency","depending","algorithms","computationally","convolution","convolutions","important","convergent","decomposition","parallelism","convolutional","implementations","converging","benchmarking","implement","specifics","architectures","concurrent","performance","architecture","computation","available","programming","processors","questions","candidates","efficiently","prediction","arbitrary","comprehension","extraction","extractive","decreases","answering","representations","published","selection","predictions","presenting","understanding","typically","formulations","recurrent","simulations","applicable","simulation","conventional","balancing","reinforcement","avoidance","backwards","manipulation","exploration","technique","anticipation","detections","consistencies","maximization","temporally","analyzing","localization","exploited","generation","conducted","challenging","effectiveness","independently","achieving","untrimmed","detection","demonstrate","additional","component","annotation","similarity","difficulty","different","dictionaries","automatically","generating","unstructured","presented","dictionary","structured","replacing","automated","intermediate","dirichlet","including","minibatch","experiments","optimization","stochastic","framework","corresponds","regression","superiority","motivates","consequently","necessity","reduction","computational","developed","convergence","practical","borrowing","theoretical","efficient","development","diagnosis","biomedical","approximately","describes","participation","participants","challenge","dermoscopic","concluded","international","classification","snapshots","segmentation","submissions","standardized","benchmark","comparative","collaboration","implementation","generated","knowledge","observations","represent","benefiting","information","dimensional","optimality","behaviors","designing","guarantees","sophisticated","experimentally","navigation","activations","termination","successful","probability","usefulness","possibility","vagueness","uncertain","especially","advocates","uncertainty","correction","translation","processing","distribution","strategies","experiment","generates","candidate","observation","fragments","automatic","incorrect","correctness","syntactic","corrections","corrector","proprietary","categorical","algorithmic","leveraging","completely","magnitude","certificate","alternative","interpretable","construct","according","consumption","empirical","structures","nonstationary","appropriate","artifacts","assumptions","applicability","univariate","predicting","seasonality","transformations","specifically","multivariate","dependent","simulated","expanding","investigate","reconstructing","overcomplete","application","validation","addresses","combination","inpainting","attention","interesting","functions","parameter","likelihood","properties","distributions","transitivity","generalized","corresponding","statistics","generalization","visualize","experimental","inflection","effective","retrieval","morphological","extracting","languages","incorrectly","correctly","predicted","challenges","significant","heterogeneous","aggregated","applications","recommendation","individual","correlated","considered","comparable" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	minibatch
# 	stepsizes
# 	inflation
# 	jackknife
# 	marginalised
# 	emphdirectly
# 	landscapes
# 	criticality
# 	criticism
# 	minibatches
# 	intermittent
# 	collinearity
# 	procrustes
# 	confounder
# 	confounders
# 	dependences
# 	recommended
# 	heteroscedastic
# 	practiced
# 	unprocessed
# Some words which never appear in Statistics papers:
# 	specifics
# 	comprehension
# 	extractive
# 	avoidance
# 	backwards
# 	anticipation
# 	consistencies
# 	untrimmed
# 	participation
# 	dermoscopic
# 	concluded
# 	snapshots
# 	termination
# 	vagueness
# 	syntactic
# 	corrector
# 	inflection
# 	integrity
# 	satisfiability
# 	humanities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0413625304136255e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
